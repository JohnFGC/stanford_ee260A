# %% [markdown]
# # Bundle Adjustment SLAM in 2D
#
# STUDENT VERSION.
#
# Students: Please open a terminal and run `pip install -r requirements.txt` before proceeding.

# %%
# Import standard packages
# For vectorized operations and linear algebra
import numpy as np
# For plotting
import matplotlib.pyplot as plt
# For loading in the CSV data as a proper table (i.e., dataframe)
import pandas as pd

# Import the key packages for gtsam
# The top level package
import gtsam
# As implied, the plotting tools
import gtsam.utils.plot as gtsam_plot
# Convenience methods for landmarks (L) and states (X)
# These need to be reset if defined later
from gtsam.symbol_shorthand import L, X

# %% [markdown]
# Now we need to load in the data. Click the folder icon at left. This is your directory. Drag the `robot_history_{num}.csv` files into the panel that appears. You will have to repeat this if you restart the Google Colab session.

# %%
# Load in the data as a table

# You will come back to change this at the end
### TODO (Q4.b and Q4.g) ###
robot_gt_df = pd.read_csv('robot_history_10.csv') # this is GROUND TRUTH (gt)!
###

# Data is (time), (x, y, theta), (speed, dtheta), (measurements)
n_time_steps, n_params = robot_gt_df.shape
n_landmarks = (n_params - (1 + 3 + 2)) // 2

print(f"Data contains {n_time_steps} time steps and {n_landmarks} landmarks.\n")
robot_gt_df
# Out:
# Data contains 11 time steps and 12 landmarks.
#     # time     x    y     theta  speed    dtheta   range_0   range_1  \
# 0      0.0   0.0  0.0  0.000000    3.0  0.000000  1.414214  1.414214
# 1      1.0   3.0  0.0  0.000000    3.0  0.000000  4.123106  4.123106
# 2      2.0   6.0  0.0  0.000000    3.0  0.000000  7.071068  7.071068
# 3      3.0   9.0  0.0  0.000000    3.0  1.570796       NaN       NaN
# 4      4.0  12.0  0.0  1.570796    2.5  0.000000       NaN       NaN
# 5      5.0  12.0  2.5  1.570796    2.5  1.570796       NaN       NaN
# 6      6.0  12.0  5.0 -3.141593    3.0  0.000000       NaN       NaN
# 7      7.0   9.0  5.0 -3.141593    3.0  0.000000       NaN       NaN
# 8      8.0   6.0  5.0 -3.141593    3.0  0.000000  9.219544  8.062258
# 9      9.0   3.0  5.0 -3.141593    3.0  0.000000  7.211103  5.656854
# 10    10.0   0.0  5.0 -3.141593    0.0  0.000000  6.082763  4.123106
#
#      range_2   range_3  ...   bearing_2   bearing_3   bearing_4   bearing_5  \
# 0   5.099020  7.071068  ...   11.309932    8.130102         NaN         NaN
# 1   2.236068  4.123106  ...   26.565051   14.036243    8.130102   -6.340192
# 2   1.414214  1.414214  ...  135.000000   45.000000   14.036243   -9.462322
# 3   4.123106  2.236068  ...  165.963757  153.434949   45.000000  -18.434949
# 4   7.071068  5.099020  ...   81.869898   78.690068   63.434949 -180.000000
# 5   7.158911  5.220153  ...  102.094757  106.699244  126.869898 -180.000000
# 6   8.062258  6.403124  ...   29.744881   38.659808   63.434949   90.000000
# 7   5.656854  4.472136  ...   45.000000   63.434949  104.036243  116.565051
# 8   4.123106  4.123106  ...   75.963757  104.036243  135.000000  135.000000
# 9   4.472136  5.656854  ...  116.565051  135.000000  150.255119         NaN
# 10  6.403124  8.062258  ...  141.340192  150.255119         NaN         NaN
#
#      bearing_6   bearing_7   bearing_8   bearing_9  bearing_10  bearing_11
# 0          NaN         NaN   29.744881   38.659808  104.036243   99.462322
# 1          NaN   29.744881   45.000000   63.434949  135.000000  123.690068
# 2    45.000000   45.000000   75.963757  104.036243  150.255119  139.398705
# 3    63.434949   75.963757  116.565051  135.000000         NaN         NaN
# 4     0.000000   26.565051   51.340192   60.255119         NaN         NaN
# 5     0.000000   53.130102   73.300756   77.905243         NaN         NaN
# 6   -90.000000   26.565051   11.309932    8.130102         NaN         NaN
# 7  -161.565051  135.000000   26.565051   14.036243         NaN         NaN
# 8  -170.537678  165.963757  135.000000   45.000000    8.130102   -8.130102
# 9  -173.659808  171.869898  165.963757  153.434949   14.036243  -14.036243
# 10         NaN         NaN  171.869898  168.690068   45.000000  -45.000000
#
# [11 rows x 30 columns]

# %% [markdown]
# ## Adding noise
#
# The data provided is ground truth. The code below adds the required noise. You can change these, but you should put everything back to the original settings when you submit

# %%
## Code to roll out the trajectory

def step_robot_pose(pose_curr: np.ndarray, speed: float, delta_theta: float):
    """
    Take the speed and turn to update the 2D pose.
    """
    # Unpack the pose
    x, y, theta = pose_curr

    # Update the position
    x += speed * np.cos(theta)
    y += speed * np.sin(theta)

    # Update the angle at the END of the step
    theta += delta_theta

    # Wrap the angle to [-pi, pi]
    theta = (theta + np.pi) % (2 * np.pi) - np.pi

    # Pack the pose back up
    return np.array([x, y, theta])

def rollout_robot_pose(pose_start: np.ndarray,
                       speeds: np.ndarray,
                       delta_thetas: np.ndarray,
                       ignore_last: bool = True):
    """
    Take the starting pose and step multiple times to get a roll out from the
    starting pose.
    """
    pose_list = [pose_start]
    pose_curr = pose_start.copy()

    for speed, delta_theta in zip(speeds, delta_thetas):
        pose_curr = step_robot_pose(pose_curr, speed, delta_theta)
        pose_list.append(pose_curr)

    if ignore_last:
        pose_list.pop()

    return np.array(pose_list)

# %%
# Create noise models

# For the submission use noise_factor = 1, but you may find it helpful to use
# noise_factor = 1e-3 for testing your code.
noise_factor = 1

# NUMPY VERSIONS
# Feel free to change the numbers, just be sure to change them back for the
# homework submission.
# We assume "pretty good starting"
PRIOR_NOISE_NUMPY = noise_factor * np.array([0.1, 0.1, np.deg2rad(1)])
# 0.3 units in x and y, and 20 degree error in angle, perhaps from wheel encoder
ODOMETRY_NOISE_NUMPY = noise_factor * np.array([0.3, 0.3, np.deg2rad(20)])
# We assume the LIDAR measurements are a lot cleaner
# 0.01 in x and y, and 0.01 degree error in angle
MEASUREMENT_NOISE_NUMPY =  noise_factor * np.array([0.01, np.deg2rad(0.01)])

# GTSAM versions

PRIOR_NOISE = gtsam.noiseModel.Diagonal.Sigmas(noise_factor * PRIOR_NOISE_NUMPY)
ODOMETRY_NOISE = gtsam.noiseModel.Diagonal.Sigmas(noise_factor * ODOMETRY_NOISE_NUMPY)
MEASUREMENT_NOISE = gtsam.noiseModel.Diagonal.Sigmas(noise_factor * MEASUREMENT_NOISE_NUMPY)

# %%
# Make a dataframe but with the noisy data
robot_noisy_df = robot_gt_df.copy()

# The random seed is for sanity, to make sure you can run the notebook again
# and get the exact same plots.
np.random.seed(273)
robot_noisy_df["speed"] += np.random.normal(0, ODOMETRY_NOISE_NUMPY[0], n_time_steps)
robot_noisy_df["dtheta"] += np.random.normal(0, ODOMETRY_NOISE_NUMPY[-1], n_time_steps)

# again, we are using "near-perfect initialization" or "relative to initialization"
# So, no noise is added to the initial pose
inital_pose = robot_gt_df[["x", "y", "theta"]].iloc[0].to_numpy()
robot_noisy_df[["x", "y", "theta"]] = rollout_robot_pose(
    inital_pose, robot_noisy_df["speed"], robot_noisy_df["dtheta"])

# add noise to the measurements
# Loop through the landmarks for range and bearing
for l_ind in range(n_landmarks):
    robot_gt_df[f"range_{l_ind}"] += np.random.normal(0, MEASUREMENT_NOISE_NUMPY[0], n_time_steps)
    robot_gt_df[f"bearing_{l_ind}"] += np.random.normal(0, MEASUREMENT_NOISE_NUMPY[1], n_time_steps)

robot_noisy_df
# Out:
#     # time          x         y     theta     speed    dtheta   range_0  \
# 0      0.0   0.000000  0.000000  0.000000  3.254924 -0.070605  1.414214
# 1      1.0   3.254924  0.000000 -0.070605  3.008145 -0.210278  4.123106
# 2      2.0   6.255575 -0.212213 -0.280883  3.222176  0.330512  7.071068
# 3      3.0   9.351478 -1.105413  0.049630  3.310150  2.089231       NaN
# 4      4.0  12.657552 -0.941200  2.138860  2.482692 -0.335601       NaN
# 5      5.0  11.321861  1.151571  1.803259  2.678351  1.677509       NaN
# 6      6.0  10.704836  3.757880 -2.802417  3.001207 -0.221030       NaN
# 7      7.0   7.874610  2.759347 -3.023447  2.853366  0.082388       NaN
# 8      8.0   5.041135  2.423018 -2.941059  2.969787 -0.219678  9.219544
# 9      9.0   2.130861  1.831459  3.122448  2.694623  0.190524  7.211103
# 10    10.0  -0.563267  1.883044 -2.970214 -0.454075  0.975938  6.082763
#
#      range_1   range_2   range_3  ...   bearing_2   bearing_3   bearing_4  \
# 0   1.414214  5.099020  7.071068  ...   11.309932    8.130102         NaN
# 1   4.123106  2.236068  4.123106  ...   26.565051   14.036243    8.130102
# 2   7.071068  1.414214  1.414214  ...  135.000000   45.000000   14.036243
# 3        NaN  4.123106  2.236068  ...  165.963757  153.434949   45.000000
# 4        NaN  7.071068  5.099020  ...   81.869898   78.690068   63.434949
# 5        NaN  7.158911  5.220153  ...  102.094757  106.699244  126.869898
# 6        NaN  8.062258  6.403124  ...   29.744881   38.659808   63.434949
# 7        NaN  5.656854  4.472136  ...   45.000000   63.434949  104.036243
# 8   8.062258  4.123106  4.123106  ...   75.963757  104.036243  135.000000
# 9   5.656854  4.472136  5.656854  ...  116.565051  135.000000  150.255119
# 10  4.123106  6.403124  8.062258  ...  141.340192  150.255119         NaN
#
#      bearing_5   bearing_6   bearing_7   bearing_8   bearing_9  bearing_10  \
# 0          NaN         NaN         NaN   29.744881   38.659808  104.036243
# 1    -6.340192         NaN   29.744881   45.000000   63.434949  135.000000
# 2    -9.462322   45.000000   45.000000   75.963757  104.036243  150.255119
# 3   -18.434949   63.434949   75.963757  116.565051  135.000000         NaN
# 4  -180.000000    0.000000   26.565051   51.340192   60.255119         NaN
# 5  -180.000000    0.000000   53.130102   73.300756   77.905243         NaN
# 6    90.000000  -90.000000   26.565051   11.309932    8.130102         NaN
# 7   116.565051 -161.565051  135.000000   26.565051   14.036243         NaN
# 8   135.000000 -170.537678  165.963757  135.000000   45.000000    8.130102
# 9          NaN -173.659808  171.869898  165.963757  153.434949   14.036243
# 10         NaN         NaN         NaN  171.869898  168.690068   45.000000
#
#     bearing_11
# 0    99.462322
# 1   123.690068
# 2   139.398705
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8    -8.130102
# 9   -14.036243
# 10  -45.000000
#
# [11 rows x 30 columns]

# %% [markdown]
# ## (Q4.b-c) Building the factor graph

# %%
# Re-import here so that you can rerun this cell to debug without rerunning
# everything
from gtsam.symbol_shorthand import L, X

# Create an empty nonlinear factor graph
### TODO (Q4.b) ###
graph = gtsam.NonlinearFactorGraph()
###

Xs = [X(i) for i in range(n_time_steps)]
Ls = [L(i) for i in range(n_landmarks)]

# Add a prior factor at the origin to set the origin of the SLAM problem
### TODO (Q4.b) ###
graph.add(gtsam.PriorFactorPose2(Xs[0], gtsam.Pose2(0.0, 0.0, 0.0), PRIOR_NOISE))

###

# Loop through the noisy data (i.e., `robot_noisy_df`)
# In the loop,
#    get the relative motion with pose_{i} - pose_{i - 1}
#    the measurements are in the noisy data
# Don't forget the loop closure constraint
### TODO (Q4.c) ####
for i in range(1, len(robot_noisy_df)):
    prev = robot_noisy_df.iloc[i-1]
    curr = robot_noisy_df.iloc[i]
    
    prev_pose = gtsam.Pose2(prev["x"], prev["y"], prev["theta"])
    curr_pose = gtsam.Pose2(curr["x"], curr["y"], curr["theta"])
    rel_pose = prev_pose.between(curr_pose)
    
    graph.add(gtsam.BetweenFactorPose2(Xs[i-1], Xs[i], rel_pose, ODOMETRY_NOISE))

    
for i in range(len(robot_noisy_df)):
    row = robot_noisy_df.iloc[i]
    for j in range(n_landmarks):
        range_col = f"range_{j}"
        bearing_col = f"bearing_{j}"
        if pd.notna(row[range_col]) and pd.notna(row[bearing_col]):
            bearing = gtsam.Rot2.fromDegrees(row[bearing_col])
            graph.add(gtsam.BearingRangeFactor2D(Xs[i], Ls[j], bearing, row[range_col], MEASUREMENT_NOISE))
            
loop_pose = gtsam.Pose2(0.0, 5.0, np.pi)
graph.add(gtsam.BetweenFactorPose2(Xs[2], Xs[8], loop_pose, ODOMETRY_NOISE))
###

# Print the factor graph to see all the nodes
### TODO (Q4.c) ####
print(graph)
###
# Out:
# NonlinearFactorGraph: size: 114
#
# Factor 0: PriorFactor on x0
#   prior mean:  (0, 0, 0)
#   noise model: diagonal sigmas [0.1; 0.1; 0.0174532925];
#
# Factor 1: BetweenFactor(x0,x1)
#   measured:  (3.25492435, 0, -0.0706048005)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 2: BetweenFactor(x1,x2)
#   measured:  (3.00814534, 2.77555756e-17, -0.210278091)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 3: BetweenFactor(x2,x3)
#   measured:  (3.22217637, 0, 0.330512456)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 4: BetweenFactor(x3,x4)
#   measured:  (3.31014995, 0, 2.08923065)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 5: BetweenFactor(x4,x5)
#   measured:  (2.48269205, 0, -0.335600897)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 6: BetweenFactor(x5,x6)
#   measured:  (2.67835095, -1.77635684e-15, 1.67750945)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 7: BetweenFactor(x6,x7)
#   measured:  (3.0012071, 4.4408921e-16, -0.221030251)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 8: BetweenFactor(x7,x8)
#   measured:  (2.85336622, 0, 0.08238768)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 9: BetweenFactor(x8,x9)
#   measured:  (2.96978709, -2.22044605e-16, -0.219678251)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 10: BetweenFactor(x9,x10)
#   measured:  (2.69462262, 0, 0.190523537)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];
#
# Factor 11: BearingRangeFactor
# Factor 11:   keys = { x0 l0 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -2.35619449
# range  1.41421356
#
# Factor 12: BearingRangeFactor
# Factor 12:   keys = { x0 l1 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  1.41421356
#
# Factor 13: BearingRangeFactor
# Factor 13:   keys = { x0 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.19739556
# range  5.09901951
#
# Factor 14: BearingRangeFactor
# Factor 14:   keys = { x0 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.141897055
# range  7.07106781
#
# Factor 15: BearingRangeFactor
# Factor 15:   keys = { x0 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.519146114
# range  8.06225775
#
# Factor 16: BearingRangeFactor
# Factor 16:   keys = { x0 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.674740942
# range  6.40312424
#
# Factor 17: BearingRangeFactor
# Factor 17:   keys = { x0 l10 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.81577499
# range  4.12310563
#
# Factor 18: BearingRangeFactor
# Factor 18:   keys = { x0 l11 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.735945
# range  6.08276253
#
# Factor 19: BearingRangeFactor
# Factor 19:   keys = { x1 l0 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -2.89661399
# range  4.12310563
#
# Factor 20: BearingRangeFactor
# Factor 20:   keys = { x1 l1 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.89661399
# range  4.12310563
#
# Factor 21: BearingRangeFactor
# Factor 21:   keys = { x1 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.463647609
# range  2.23606798
#
# Factor 22: BearingRangeFactor
# Factor 22:   keys = { x1 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.244978663
# range  4.12310563
#
# Factor 23: BearingRangeFactor
# Factor 23:   keys = { x1 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.141897055
# range  7.07106781
#
# Factor 24: BearingRangeFactor
# Factor 24:   keys = { x1 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -0.110657221
# range  9.05538514
#
# Factor 25: BearingRangeFactor
# Factor 25:   keys = { x1 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.519146114
# range  8.06225775
#
# Factor 26: BearingRangeFactor
# Factor 26:   keys = { x1 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  5.65685425
#
# Factor 27: BearingRangeFactor
# Factor 27:   keys = { x1 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.10714872
# range  4.47213595
#
# Factor 28: BearingRangeFactor
# Factor 28:   keys = { x1 l10 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  5.65685425
#
# Factor 29: BearingRangeFactor
# Factor 29:   keys = { x1 l11 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.15879893
# range  7.21110255
#
# Factor 30: BearingRangeFactor
# Factor 30:   keys = { x2 l0 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -2.9996956
# range  7.07106781
#
# Factor 31: BearingRangeFactor
# Factor 31:   keys = { x2 l1 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.9996956
# range  7.07106781
#
# Factor 32: BearingRangeFactor
# Factor 32:   keys = { x2 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  1.41421356
#
# Factor 33: BearingRangeFactor
# Factor 33:   keys = { x2 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  1.41421356
#
# Factor 34: BearingRangeFactor
# Factor 34:   keys = { x2 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.244978663
# range  4.12310563
#
# Factor 35: BearingRangeFactor
# Factor 35:   keys = { x2 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -0.165148677
# range  6.08276253
#
# Factor 36: BearingRangeFactor
# Factor 36:   keys = { x2 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  8.48528137
#
# Factor 37: BearingRangeFactor
# Factor 37:   keys = { x2 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  5.65685425
#
# Factor 38: BearingRangeFactor
# Factor 38:   keys = { x2 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.32581766
# range  4.12310563
#
# Factor 39: BearingRangeFactor
# Factor 39:   keys = { x2 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.81577499
# range  4.12310563
#
# Factor 40: BearingRangeFactor
# Factor 40:   keys = { x2 l10 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.62244654
# range  8.06225775
#
# Factor 41: BearingRangeFactor
# Factor 41:   keys = { x2 l11 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.43296638
# range  9.21954446
#
# Factor 42: BearingRangeFactor
# Factor 42:   keys = { x3 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.89661399
# range  4.12310563
#
# Factor 43: BearingRangeFactor
# Factor 43:   keys = { x3 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.67794504
# range  2.23606798
#
# Factor 44: BearingRangeFactor
# Factor 44:   keys = { x3 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  1.41421356
#
# Factor 45: BearingRangeFactor
# Factor 45:   keys = { x3 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -0.321750554
# range  3.16227766
#
# Factor 46: BearingRangeFactor
# Factor 46:   keys = { x3 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.10714872
# range  6.70820393
#
# Factor 47: BearingRangeFactor
# Factor 47:   keys = { x3 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.32581766
# range  4.12310563
#
# Factor 48: BearingRangeFactor
# Factor 48:   keys = { x3 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.03444394
# range  4.47213595
#
# Factor 49: BearingRangeFactor
# Factor 49:   keys = { x3 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  5.65685425
#
# Factor 50: BearingRangeFactor
# Factor 50:   keys = { x4 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.42889927
# range  7.07106781
#
# Factor 51: BearingRangeFactor
# Factor 51:   keys = { x4 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.37340077
# range  5.09901951
#
# Factor 52: BearingRangeFactor
# Factor 52:   keys = { x4 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.10714872
# range  2.23606798
#
# Factor 53: BearingRangeFactor
# Factor 53:   keys = { x4 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -3.14159265
# range  1
#
# Factor 54: BearingRangeFactor
# Factor 54:   keys = { x4 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0
# range  6
#
# Factor 55: BearingRangeFactor
# Factor 55:   keys = { x4 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.463647609
# range  4.47213595
#
# Factor 56: BearingRangeFactor
# Factor 56:   keys = { x4 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.896055385
# range  6.40312424
#
# Factor 57: BearingRangeFactor
# Factor 57:   keys = { x4 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.05165021
# range  8.06225775
#
# Factor 58: BearingRangeFactor
# Factor 58:   keys = { x5 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.78188966
# range  7.15891053
#
# Factor 59: BearingRangeFactor
# Factor 59:   keys = { x5 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.86225312
# range  5.22015325
#
# Factor 60: BearingRangeFactor
# Factor 60:   keys = { x5 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.21429744
# range  2.5
#
# Factor 61: BearingRangeFactor
# Factor 61:   keys = { x5 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -3.14159265
# range  3.5
#
# Factor 62: BearingRangeFactor
# Factor 62:   keys = { x5 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0
# range  3.5
#
# Factor 63: BearingRangeFactor
# Factor 63:   keys = { x5 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.927295218
# range  2.5
#
# Factor 64: BearingRangeFactor
# Factor 64:   keys = { x5 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.27933953
# range  5.22015325
#
# Factor 65: BearingRangeFactor
# Factor 65:   keys = { x5 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.35970299
# range  7.15891053
#
# Factor 66: BearingRangeFactor
# Factor 66:   keys = { x6 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.519146114
# range  8.06225775
#
# Factor 67: BearingRangeFactor
# Factor 67:   keys = { x6 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.674740942
# range  6.40312424
#
# Factor 68: BearingRangeFactor
# Factor 68:   keys = { x6 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.10714872
# range  4.47213595
#
# Factor 69: BearingRangeFactor
# Factor 69:   keys = { x6 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.57079633
# range  6
#
# Factor 70: BearingRangeFactor
# Factor 70:   keys = { x6 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -1.57079633
# range  1
#
# Factor 71: BearingRangeFactor
# Factor 71:   keys = { x6 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.463647609
# range  2.23606798
#
# Factor 72: BearingRangeFactor
# Factor 72:   keys = { x6 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.19739556
# range  5.09901951
#
# Factor 73: BearingRangeFactor
# Factor 73:   keys = { x6 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.141897055
# range  7.07106781
#
# Factor 74: BearingRangeFactor
# Factor 74:   keys = { x7 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  5.65685425
#
# Factor 75: BearingRangeFactor
# Factor 75:   keys = { x7 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.10714872
# range  4.47213595
#
# Factor 76: BearingRangeFactor
# Factor 76:   keys = { x7 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.81577499
# range  4.12310563
#
# Factor 77: BearingRangeFactor
# Factor 77:   keys = { x7 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.03444394
# range  6.70820393
#
# Factor 78: BearingRangeFactor
# Factor 78:   keys = { x7 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -2.8198421
# range  3.16227766
#
# Factor 79: BearingRangeFactor
# Factor 79:   keys = { x7 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  1.41421356
#
# Factor 80: BearingRangeFactor
# Factor 80:   keys = { x7 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.463647609
# range  2.23606798
#
# Factor 81: BearingRangeFactor
# Factor 81:   keys = { x7 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.244978663
# range  4.12310563
#
# Factor 82: BearingRangeFactor
# Factor 82:   keys = { x8 l0 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.708626272
# range  9.21954446
#
# Factor 83: BearingRangeFactor
# Factor 83:   keys = { x8 l1 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.519146114
# range  8.06225775
#
# Factor 84: BearingRangeFactor
# Factor 84:   keys = { x8 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.32581766
# range  4.12310563
#
# Factor 85: BearingRangeFactor
# Factor 85:   keys = { x8 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.81577499
# range  4.12310563
#
# Factor 86: BearingRangeFactor
# Factor 86:   keys = { x8 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  5.65685425
#
# Factor 87: BearingRangeFactor
# Factor 87:   keys = { x8 l5 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  8.48528137
#
# Factor 88: BearingRangeFactor
# Factor 88:   keys = { x8 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -2.97644398
# range  6.08276253
#
# Factor 89: BearingRangeFactor
# Factor 89:   keys = { x8 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.89661399
# range  4.12310563
#
# Factor 90: BearingRangeFactor
# Factor 90:   keys = { x8 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  1.41421356
#
# Factor 91: BearingRangeFactor
# Factor 91:   keys = { x8 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  1.41421356
#
# Factor 92: BearingRangeFactor
# Factor 92:   keys = { x8 l10 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.141897055
# range  7.07106781
#
# Factor 93: BearingRangeFactor
# Factor 93:   keys = { x8 l11 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -0.141897055
# range  7.07106781
#
# Factor 94: BearingRangeFactor
# Factor 94:   keys = { x9 l0 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.982793723
# range  7.21110255
#
# Factor 95: BearingRangeFactor
# Factor 95:   keys = { x9 l1 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  5.65685425
#
# Factor 96: BearingRangeFactor
# Factor 96:   keys = { x9 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.03444394
# range  4.47213595
#
# Factor 97: BearingRangeFactor
# Factor 97:   keys = { x9 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.35619449
# range  5.65685425
#
# Factor 98: BearingRangeFactor
# Factor 98:   keys = { x9 l4 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.62244654
# range  8.06225775
#
# Factor 99: BearingRangeFactor
# Factor 99:   keys = { x9 l6 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -3.03093543
# range  9.05538514
#
# Factor 100: BearingRangeFactor
# Factor 100:   keys = { x9 l7 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.9996956
# range  7.07106781
#
# Factor 101: BearingRangeFactor
# Factor 101:   keys = { x9 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.89661399
# range  4.12310563
#
# Factor 102: BearingRangeFactor
# Factor 102:   keys = { x9 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.67794504
# range  2.23606798
#
# Factor 103: BearingRangeFactor
# Factor 103:   keys = { x9 l10 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.244978663
# range  4.12310563
#
# Factor 104: BearingRangeFactor
# Factor 104:   keys = { x9 l11 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -0.244978663
# range  4.12310563
#
# Factor 105: BearingRangeFactor
# Factor 105:   keys = { x10 l0 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.40564765
# range  6.08276253
#
# Factor 106: BearingRangeFactor
# Factor 106:   keys = { x10 l1 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 1.32581766
# range  4.12310563
#
# Factor 107: BearingRangeFactor
# Factor 107:   keys = { x10 l2 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.46685171
# range  6.40312424
#
# Factor 108: BearingRangeFactor
# Factor 108:   keys = { x10 l3 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.62244654
# range  8.06225775
#
# Factor 109: BearingRangeFactor
# Factor 109:   keys = { x10 l8 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.9996956
# range  7.07106781
#
# Factor 110: BearingRangeFactor
# Factor 110:   keys = { x10 l9 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 2.94419709
# range  5.09901951
#
# Factor 111: BearingRangeFactor
# Factor 111:   keys = { x10 l10 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : 0.785398163
# range  1.41421356
#
# Factor 112: BearingRangeFactor
# Factor 112:   keys = { x10 l11 }
#   noise model: diagonal sigmas [0.01; 0.000174532925];
# ExpressionFactor with measurement: bearing : -0.785398163
# range  1.41421356
#
# Factor 113: BetweenFactor(x2,x8)
#   measured:  (0, 5, 3.14159265)
#   noise model: diagonal sigmas [0.3; 0.3; 0.34906585];

# %% [markdown]
# ## (Q4.d) Initialize the optimization problem

# %%
# Set-up a values data structure for the initial estimate
### TODO (Q4.d) ###
initial_estimate = gtsam.Values()
###

# Set the initial poses from the noisy odometry alone
# Hint, you already have this in `robot_noisy_df`
### TODO (Q4.d) ###
for x_ind, X in enumerate(Xs):
    row = robot_noisy_df.iloc[x_ind]
    x = float(row["x"])
    y = float(row["y"])
    theta = float(row["theta"])
    pose = gtsam.Pose2(x, y, theta)
    initial_estimate.insert(X, pose)
###

# Sample random values for the initial landmark positions
# In reality, you would have to estimate these from odometry,
# but to not over-complicate the problem, just use noisy
# ground-truth.
# In reality, the initialization is very important for the
# graph optimization to converge to a good solution!!
l_init_vec = [
    (-1, -1),
    (-1, 1),
    (5, 1),
    (7, 1),
    (10, 1),
    (12, -1),
    (12, 6),
    (10, 4),
    (7, 4),
    (5, 4),
    (-1, 4),
    (-1, 6)
]

for l_ind, L in enumerate(Ls):
    l_hat = l_init_vec[l_ind]
    point_init = (np.random.normal(l_hat[0], ODOMETRY_NOISE_NUMPY[0]),
                  np.random.normal(l_hat[1], ODOMETRY_NOISE_NUMPY[0]))
    # Add the initial estimates of the landmarks
    ### TODO (Q4.d) ###
    initial_estimate.insert(L, gtsam.Point2(point_init[0], point_init[1]))
    ###

# Print the initial estimates to verify
### TODO (Q4.d) ###
print(initial_estimate)
###
# Out:
# Values with 23 values:
# Value l0: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-1.04531412;
# 	-1.21481369
# ]
#
# Value l1: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-1.00629039;
# 	1.17309668
# ]
#
# Value l2: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	4.5809314;
# 	0.992908941
# ]
#
# Value l3: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	6.58246277;
# 	0.865267077
# ]
#
# Value l4: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	9.66434412;
# 	1.08988328
# ]
#
# Value l5: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	11.5884324;
# 	-1.3857714
# ]
#
# Value l6: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	12.4511261;
# 	5.92072691
# ]
#
# Value l7: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	9.46084069;
# 	3.89537827
# ]
#
# Value l8: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	7.25516174;
# 	4.41311515
# ]
#
# Value l9: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	4.81397342;
# 	3.97336983
# ]
#
# Value l10: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-1.36212978;
# 	3.67352319
# ]
#
# Value l11: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-0.498201812;
# 	5.55854322
# ]
#
# Value x0: (gtsam::Pose2)
# (0, 0, 0)
#
# Value x1: (gtsam::Pose2)
# (3.25492435, 0, -0.0706048005)
#
# Value x2: (gtsam::Pose2)
# (6.25557495, -0.212213084, -0.280882892)
#
# Value x3: (gtsam::Pose2)
# (9.35147768, -1.10541342, 0.0496295644)
#
# Value x4: (gtsam::Pose2)
# (12.6575519, -0.94119955, 2.13886021)
#
# Value x5: (gtsam::Pose2)
# (11.321861, 1.15157128, 1.80325932)
#
# Value x6: (gtsam::Pose2)
# (10.704836, 3.75787977, -2.80241654)
#
# Value x7: (gtsam::Pose2)
# (7.87461038, 2.75934738, -3.02344679)
#
# Value x8: (gtsam::Pose2)
# (5.04113528, 2.42301767, -2.94105911)
#
# Value x9: (gtsam::Pose2)
# (2.13086141, 1.83145921, 3.12244795)
#
# Value x10: (gtsam::Pose2)
# (-0.563267406, 1.88304381, -2.97021382)

# %% [markdown]
# ## (Q4.d) Plotting

# %%
# Plot the initial poses and landmarks.
for x_ind, x_key in enumerate(Xs):
    gtsam_plot.plot_pose2(0, initial_estimate.atPose2(x_key), 0.5)

for l_ind, l_key in enumerate(Ls):
    gtsam_plot.plot_point2(0, initial_estimate.atPoint2(l_key), 0.5)


plt.axis('equal')
plt.show()

# %% [markdown]
# ## (Q4.e) Graph Optimization

# %%
# We are going to optimize with the Levenberg-Marquardt solver.
# You can definitely consider other options (e.g., Gauss Newton).
# You may be interested in AA 222: Optimization for more about these
# methods. Levenberg-Marquardt has a number of configuration
# parameters, but we will use the defaults. For your projects, you
# might consider tweaking the parameters for tighter convergence.

lm_params = gtsam.LevenbergMarquardtParams()

# uncomment the two lines below
### TODO (Q4.e)  ###
optimizer = gtsam.LevenbergMarquardtOptimizer(graph, initial_estimate,lm_params)
result = optimizer.optimize()
###

# Print the results
### TODO (Q4.e) ###
result.print("Final Result:\n")
###
# Out:
# Final Result:
#
# Values with 23 values:
# Value l0: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-0.999999729;
# 	-1.00000026
# ]
#
# Value l1: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-1.00000023;
# 	0.999999751
# ]
#
# Value l2: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	4.99999977;
# 	1.00000125
# ]
#
# Value l3: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	6.99999978;
# 	1.00000175
# ]
#
# Value l4: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	9.99999977;
# 	1.00000253
# ]
#
# Value l5: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	12.0000003;
# 	-0.999996956
# ]
#
# Value l6: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	11.9999985;
# 	6.00000304
# ]
#
# Value l7: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	9.99999901;
# 	4.00000252
# ]
#
# Value l8: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	6.99999901;
# 	4.00000176
# ]
#
# Value l9: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	4.99999901;
# 	4.00000125
# ]
#
# Value l10: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-1.00000098;
# 	3.99999975
# ]
#
# Value l11: (Eigen::Matrix<double, -1, 1, 0, -1, 1>)
# [
# 	-1.00000149;
# 	5.99999974
# ]
#
# Value x0: (gtsam::Pose2)
# (1.35550741e-17, -1.67709934e-17, -6.14587692e-18)
#
# Value x1: (gtsam::Pose2)
# (3.00000004, 7.46696731e-07, 1.01474544e-05)
#
# Value x2: (gtsam::Pose2)
# (6.00000001, 1.51147357e-06, -1.66474215e-05)
#
# Value x3: (gtsam::Pose2)
# (9.00000003, 2.27556844e-06, 4.4953513e-05)
#
# Value x4: (gtsam::Pose2)
# (12.0000001, 3.04812327e-06, 1.57088609)
#
# Value x5: (gtsam::Pose2)
# (11.9999994, 2.50000301, 1.57075785)
#
# Value x6: (gtsam::Pose2)
# (11.9999987, 5.00000306, -3.14155894)
#
# Value x7: (gtsam::Pose2)
# (8.99999874, 5.00000227, 3.14155682)
#
# Value x8: (gtsam::Pose2)
# (5.99999876, 5.0000015, -3.14156994)
#
# Value x9: (gtsam::Pose2)
# (2.99999875, 5.00000076, 3.14154483)
#
# Value x10: (gtsam::Pose2)
# (-1.21160574e-06, 5, -3.14157287)

# %%
# To understand uncertainty, you need the marginal Gaussian distributions.
# gtsam makes this directly accessible with
# marginals = gtsam.Marginals(graph, result)
# The covariance matrices are in marginals. For example, the covariance
# matrix for X(1) (i.e., Xs[0]) is
# marginals.marginalCovariance(X(1))

# Check that you can print the marginal covariance matrices for both poses
# and landmarks
### TODO (Q4.e) ###
marginals = gtsam.Marginals(graph, result)
###

# %%
# Now plot the poses and landmarks _with_ covariance ellipses.
position_out = []

for x_ind, x_key in enumerate(Xs):
    m = marginals.marginalCovariance(x_key)
    pose_result_curr = result.atPose2(x_key)
    gtsam_plot.plot_pose2(0, pose_result_curr, 0.5, m)
    position_out.append(pose_result_curr.translation())

for l_ind, l_key in enumerate(Ls):
    m = marginals.marginalCovariance(l_key)
    gtsam_plot.plot_point2(0, result.atPoint2(l_key), 0.5, m)

# Connect the dots
position_out = np.array(position_out)
plt.plot(position_out[:, 0], position_out[:, 1], "k:")

plt.axis('equal')
plt.show()
